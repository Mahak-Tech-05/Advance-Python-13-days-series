# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahak-Tech-05/Advance-Python-13-days-series/blob/main/login_from_code_for_mobile_python_developers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# !pip install pyngrok
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 48.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 67.6 MB/s eta 0:00:00
# ...

# %%
# !ngrok config add-authtoken 32udmDvCcHqAwaZIasaRXVyc4YU_2RekvYcemtSmFECQNgEMQ#use here you're own authentication token
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# %%writefile app.py

import streamlit as st

st.title("Login Form 🔐")

# Input fields
username = st.text_input("Username")
password = st.text_input("Password", type="password")

# Button logic
if st.button("Login"):
    if username == "admin" and password == "1234":
        st.success("Login Successful ✅")
    else:
        st.error("Invalid Credentials ❌")
# Out:
# Writing app.py

# %%
from pyngrok import ngrok

ngrok.kill()  # clean previous session

public_url = ngrok.connect(8501)
print("👉 Open this link:", public_url)

# !streamlit run app.py &
# Out:
# 👉 Open this link: NgrokTunnel: "https://8f4e-136-117-77-198.ngrok-free.app" -> "http://localhost:8501"
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://136.117.77.198:8501
#
#   Stopping...

# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahak-Tech-05/Advance-Python-13-days-series/blob/main/gui_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# !pip install pyngrok
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 37.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 91.8 MB/s eta 0:00:00
# ...

# %%
# %%writefile app.py

import streamlit as st

st.title("My First GUI App 🚀")

name = st.text_input("Enter your name")

if st.button("Submit"):
    st.success(f"Hello {name}, welcome to your GUI app!")
# Out:
# Writing app.py

# %%
# !pip install streamlit pyngrok

# %%
# !pip install pyngrok --quiet

# %%
from pyngrok import ngrok
ngrok.kill()

# %%
# !ngrok config add-authtoken 32udmDvCcHqAwaZIasaRXVyc4YU_2RekvYcemtSmFECQNgEMQ #here you have to make you're own account in ngrok and then copy you're token and paste it
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok

ngrok.kill()  # clean start

public_url = ngrok.connect(8501)
print("Open this link:", public_url)

# !streamlit run app.py &
# Out:
# Open this link: NgrokTunnel: "https://570b-34-106-232-227.ngrok-free.app" -> "http://localhost:8501"
#
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.232.227:8501
#
#   Stopping...

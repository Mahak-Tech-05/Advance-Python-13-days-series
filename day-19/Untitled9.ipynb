# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahak-Tech-05/Advance-Python-13-days-series/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

conn = sqlite3.connect("student.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS students (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT,
    age INTEGER,
    course TEXT
)
""")

cursor.execute("INSERT INTO students (name, age, course) VALUES (?, ?, ?)",
               ("Mahak", 19, "BSc"))

conn.commit()

cursor.execute("SELECT * FROM students")
print(cursor.fetchall())
# Out:
# [(1, 'Mahak', 19, 'BSc'), (2, 'Mahak', 19, 'BSc'), (3, 'Mahak', 19, 'BSc')]

# %%
cursor.execute("SELECT  * FROM students WHERE id=1")
print(cursor.fetchall())
# Out:
# [(1, 'Mahak', 19, 'BSc')]
